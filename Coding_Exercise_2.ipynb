# %%
# !pip install google-genai

# %%
from google import genai

# Setup your API key - remember to paste your real key here!
client = genai.Client(api_key="AIzaSyAHgOuSRmh5-UhFQaycZehdJy-uQrc3cao")

# Updated concept: Major Recording Studio Album Sales
react_prompt = """
You are a Lead Data Analyst at a major recording studio company. I need Python code to generate a synthetic dataset of 50 recent album releases and calculate the average revenue.

Follow the ReACT framework explicitly to formulate your response:
1. Thought: Reason about the steps needed (import libraries, generate realistic album names and sales data, calculate the average revenue, and identify the top-selling album).
2. Action: Write the Python code to execute the plan.
3. Observation: Print the final average revenue and the top-selling album to observe the results.

Constraints:
- Use the 'random' and 'pandas' libraries.
- Output ONLY valid, executable Python code.
- Do NOT wrap the code in markdown formatting (no ```python or ``` blocks).
- Do not include any conversational text outside of the code.
- Include brief comments in the code to explain your logic.
"""

# Using the stable model we established earlier
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=react_prompt
)

# Cleaning up the output just in case the AI stubbornly adds markdown blocks
generated_code = response.text.replace('```python', '').replace('```', '').strip()

print("--- Generated Code ---")
print(generated_code)

print("\n--- Execution Output ---")
# This command actually runs the Python code the AI just wrote!
try:
    exec(generated_code)
except Exception as e:
    print(f"The generated code had an error: {e}")
# Out:
# --- Generated Code ---
# import random
# import pandas as pd
# from datetime import datetime, timedelta
#
# # --- Thought: Reason about the steps needed ---
# # 1. Import necessary libraries: 'random' for data generation, 'pandas' for DataFrame operations.
# # 2. Define lists of potential values for album names, artists, and genres to ensure variety.
# # 3. Generate 50 synthetic album entries:
# #    - Combine random words for album titles.
# #    - Pick random artists and genres from predefined lists.
# #    - Generate a recent release date (e.g., within the last 2 years).
# #    - Generate realistic units sold (e.g., 50,000 to 5,000,000).
# #    - Generate realistic price per unit (e.g., $9.99 to $19.99).
# #    - Calculate total revenue for each album (Units Sold * Price Per Unit).
# # 4. Create a pandas DataFrame from the generated data.
# # 5. Calculate the average revenue across all albums.
# # 6. Identify the top-selling album based on its total revenue.
# ...
