# %%
# !pip install google-genai

# %%
from google import genai

# Setup your API key - paste your real key here!
client = genai.Client(api_key="AIzaSyAHgOuSRmh5-UhFQaycZehdJy-uQrc3cao")

# Step 1: Generate Original Summary
prompt_original = "Write a summary explaining how Machine Learning is used to detect patterns in music and movie production."

response_1 = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=prompt_original
)
original_summary = response_1.text.strip()

print("--- Original Summary ---")
print(original_summary)

# Step 2: Self-Reflection and Improvement Prompt
prompt_reflection = f"""
Below is a summary of how Machine Learning is used to analyze and detect patterns in music and movie production.
<summary>
{original_summary}
</summary>

Critique the summary against the following strict requirements:
1. Length Limit: Is it exactly two paragraphs long?
2. Formatting: Does it include a bulleted list highlighting exactly three specific ML applications (e.g., hit song prediction, script structure analysis, audience targeting)?
3. Audience: Is the vocabulary simple and accessible enough for a non-technical creative producer or artist to understand?

First, output your critique explaining where the original summary failed. Then, output a revised version of the summary that perfectly aligns with all these requirements.
Clearly label the critique section as "CRITIQUE" and the revised summary as "REVISED SUMMARY".
"""

response_2 = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=prompt_reflection
)
improved_output = response_2.text.strip()

print("\n--- Self-Critique & Improved Summary ---")
print(improved_output)
# Out:
# --- Original Summary ---
# Machine Learning (ML) plays a pivotal role in music and movie production by leveraging its ability to identify, analyze, and predict intricate patterns within vast amounts of data. This allows for enhanced creativity, efficiency, and audience engagement across various stages of production.
#
# Here's how it's used:
#
# ### In Music Production:
#
# 1.  **Melodic, Harmonic, and Rhythmic Analysis:**
#     *   ML algorithms can dissect existing musical pieces to understand common chord progressions, melodic contours, rhythmic structures, and even the emotional qualities associated with different musical phrases.
#     *   **Pattern Detection:** They identify recurring themes, motifs, and stylistic signatures that define genres or individual artists. For instance, an ML model can learn what makes a song "pop" versus "jazz" by analyzing thousands of examples.
# 2.  **Algorithmic Composition and Generation:**
# ...
