# %%
# !pip install google-genai

# %%
from google import genai

# Setup your API key
client = genai.Client(api_key="AIzaSyAHgOuSRmh5-UhFQaycZehdJy-uQrc3cao")

# --- DIAGNOSTIC: Print available models ---
print("Models available to your API key:")
try:
    for m in client.models.list():
        # Just printing the first few to keep it clean
        if "flash" in m.name or "pro" in m.name:
            print(f"- {m.name}")
except Exception as e:
    print("Could not list models:", e)
print("-" * 40)
# ------------------------------------------

# We are upgrading to the latest 2.5 flash model
model_name = 'gemini-2.5-flash'

customer_email = "I ordered the Streetwear Jacket in black, but it arrived with a tear on the sleeve. Is it possible to find replacement before my trip next week."

# Step 1: Classify the Issue
prompt_1 = f"""
Analyze the following customer email and classify the core issue into one of these categories: [Shipping Delay, Product Quality, Billing Error, General Inquiry].
Only output the category name and nothing else.
Email: "{customer_email}"
"""
response_1 = client.models.generate_content(model=model_name, contents=prompt_1)
step1_output = response_1.text.strip()
print(f"Step 1 (Classification): {step1_output}")

# Step 2: Gather Missing Information based on Classification
prompt_2 = f"""
The customer issue has been classified as: {step1_output}.
Here is their original email: "{customer_email}"
Identify what required information is missing to process a '{step1_output}' claim.
Required info for Product Quality: Order Number, Photo of Damage, Preferred Resolution.
Output strictly a comma-separated list of the missing information.
"""
response_2 = client.models.generate_content(model=model_name, contents=prompt_2)
step2_output = response_2.text.strip()
print(f"\nStep 2 (Missing Info): {step2_output}")

# Step 3: Formulate Final Response
prompt_3 = f"""
You are a customer support agent for a streetwear apparel company based in San Jose.
Draft a reply to the customer.
Original Email: "{customer_email}"
Missing Information needed: {step2_output}
Constraints: Keep the tone professional, concise, and helpful. Do not be overly apologetic. Ask clearly for the missing information so we can process their replacement.
"""
response_3 = client.models.generate_content(model=model_name, contents=prompt_3)
step3_output = response_3.text.strip()
print(f"\nStep 3 (Final Response):\n{step3_output}")
# Out:
# Models available to your API key:
# - models/gemini-2.5-flash
# - models/gemini-2.5-pro
# - models/gemini-2.0-flash
# - models/gemini-2.0-flash-001
# - models/gemini-2.0-flash-exp-image-generation
# - models/gemini-2.0-flash-lite-001
# - models/gemini-2.0-flash-lite
# - models/gemini-2.5-flash-preview-tts
# - models/gemini-2.5-pro-preview-tts
# - models/gemini-flash-latest
# - models/gemini-flash-lite-latest
# - models/gemini-pro-latest
# - models/gemini-2.5-flash-lite
# - models/gemini-2.5-flash-image
# - models/gemini-2.5-flash-lite-preview-09-2025
# - models/gemini-3-pro-preview
# - models/gemini-3-flash-preview
# - models/gemini-3.1-pro-preview
# - models/gemini-3.1-pro-preview-customtools
# - models/gemini-3.1-flash-lite-preview
# - models/gemini-3-pro-image-preview
# - models/nano-banana-pro-preview
# - models/gemini-3.1-flash-image-preview
# - models/deep-research-pro-preview-12-2025
# - models/gemini-2.5-flash-native-audio-latest
# ...
